# %%
Friuts = ["Apple", "Mango", "Banana"]

print("My favourite friuts are", Friuts)

print(Friuts[0])
print(Friuts[1])
print(Friuts[2])
# Out:
# My favourite friuts are ['Apple', 'Mango', 'Banana']
# Apple
# Mango
# Banana

# %%
D = {

     "Abdullah": 18,
     "Abdul Rehman": 21,
     "Abdul Subhan": 17
}

print("Broters and their ages:", D)

print("Abdullah is", D["Abdullah"], "years old")
print("Abdul Rehman is", D["Abdul Rehman"], "years old")
print("Abdul Subhan is", D["Abdul Subhan"], "years old")
# Out:
# Broters and their ages: {'Abdullah': 18, 'Abdul Rehman': 21, 'Abdul Subhan': 17}
# Abdullah is 18 years old
# Abdul Rehman is 21 years old
# Abdul Subhan is 17 years old
