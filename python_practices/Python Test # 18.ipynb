# %%
num = int(input("Entert the number: "))

i = 0

if num > 0:
  while (i < num + 1):
    if i % 3 == 0 and i % 5 != 0:
      print(i)

    i += 1

else:
  print('Please enter the number which is greater than 0')
# Out:
# Entert the number: 20
# 3
# 6
# 9
# 12
# 18
