# %%
# Create dictionary

D = {'Name':'Abdullah', 'Age':18}
print(D)
# Out:
# {'Name': 'Abdullah', 'Age': 18}

# %%
# Create empty dictionary

D ={}
print(D)
# Out:
# {}

# %%
D1 = {(1,2,3):'abdullah'}
print(D1)
# Out:
# {(1, 2, 3): 'abdullah'}

# %%
D2 = {'Name':'abdullah', 'Name':'Abdul Subhan'}
print(D2)
# Out:
# {'Name': 'Abdul Subhan'}

# %%
# Accessing value from a dictionary

D3 = {'Name':'Abdullah', 'Age':18}
print(D3['Age'])
# Out:
# 18

# %%
# Accessing value from a 2D dictionary

D4 = {'Name':'Abdulah', 'Age':18, 'College':'Cant clollege', 'Marks':{'Math':67, 'Eng':89, 'Chem':56, 'Phy':78}}
print(D4['Marks']['Eng'])
# Out:
# 89

# %%
D['Age'] = 19
print(D)
# Out:
# {'Name': 'Abdullah', 'Age': 19}

# %%
D4['Marks']['Eng'] = 95
print(D4)
# Out:
# {'Name': 'Abdulah', 'Age': 18, 'College': 'Cant clollege', 'Marks': {'Math': 67, 'Eng': 95, 'Chem': 56, 'Phy': 78}}

# %%
D5 = {}
D5
# Out:
# {}

# %%
del D5
D5
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-40-10f48e8e5ff3> in <cell line: 2>()
#       1 del D5
# ----> 2 D5
#
# NameError: name 'D5' is not defined

# %%
del D4['College']
print(D4)
# Out:
# {'Name': 'Abdulah', 'Age': 18, 'Marks': {'Math': 67, 'Eng': 95, 'Chem': 56, 'Phy': 78}}

# %%
D4.get('Marks')
# Out:
# {'Math': 67, 'Eng': 95, 'Chem': 56, 'Phy': 78}

# %%
D1
# Out:
# {(1, 2, 3): 'abdullah'}

# %%
D1.clear()
D1
# Out:
# {}

# %%
'Name' in D4
# Out:
# True

# %%
min(D4)
# Out:
# 'Age'

# %%
max(D4)
# Out:
# 'Name'

# %%
sorted(D4)
# Out:
# ['Age', 'Marks', 'Name']

# %%
print(D4)
# Out:
# {'Name': 'Abdulah', 'Age': 18, 'Marks': {'Math': 67, 'Eng': 95, 'Chem': 56, 'Phy': 78}}

# %%
D4.keys()
# Out:
# dict_keys(['Name', 'Age', 'Marks'])

# %%
D4.values()
# Out:
# dict_values(['Abdulah', 18, {'Math': 67, 'Eng': 95, 'Chem': 56, 'Phy': 78}])

# %%
students = {1:{"Name":"Emma","Age":27,"Roll":108}, 2:{"Name":"Mike","Age":22,"Roll":102}}
print(students[1]["Age"])
# Out:
# 27
