# %% [markdown]
# # **Q : 1**

# %%
aList = [10, 20, 30, 40, 50, 60, 70, 80]
print(aList[2:5])
print(aList[:4])
print(aList[3:])
# Out:
# [30, 40, 50]
# [10, 20, 30, 40]
# [40, 50, 60, 70, 80]

# %% [markdown]
# # **Q : 2**

# %%
sampleList = [10, 20, 30, 40, 50]
sampleList.pop()
print(sampleList)

sampleList.pop(2)
print(sampleList)
# Out:
# [10, 20, 30, 40]
# [10, 20, 40]

# %% [markdown]
# # **Q : 3**

# %%
l = [None] * 10
print(len(l))
# Out:
# 10

# %% [markdown]
# # **Q : 4**

# %%
my_list = ["Hello", "Python"]
print("-".join(my_list))
# Out:
# Hello-Python
