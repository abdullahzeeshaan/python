# %% [markdown]
# # **Find the factorial of the given number**

# %%
num = int(input("Enter the number: "))

factorial = 1

if num > 0:
  while (num > 0):
    factorial = factorial * num
    num = num - 1

  print(factorial)

else:
  print("Please input the positive numbers")
# Out:
# Enter the number: 10
# 3628800
