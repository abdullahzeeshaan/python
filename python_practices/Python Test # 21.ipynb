# %%
num = int(input("Enter the number: "))

table = lambda x : [f'{x} * {i} = {x * i}' for i in range(1, 10 + 1)]
print('\n'.join(table(num)))
# Out:
# Enter the number: 100
# 100 * 1 = 100
# 100 * 2 = 200
# 100 * 3 = 300
# 100 * 4 = 400
# 100 * 5 = 500
# 100 * 6 = 600
# 100 * 7 = 700
# 100 * 8 = 800
# 100 * 9 = 900
# 100 * 10 = 1000
