# %%
F_Name = input("Enter your first name")
L_Name = input("Enter your last name")
Age = int(input("Enter your first name"))

print(f'''Hello {F_Name} {L_Name}! You are {Age} years old.''')
# Out:
# Enter your first nameAbdullah
# Enter your last nameZeeshan
# Enter your first name18
# Hello Abdullah Zeeshan! You are 18 years old.

# %%
Var1 = "Hello"
Var2 = 50
Var3 = 7.89

print(type(Var1))
print(type(Var2))
print(type(Var3))
# Out:
# <class 'str'>
# <class 'int'>
# <class 'float'>
