# %%
Alphabet = input("Enter the alphabet: ")

if Alphabet == 'a':
  print(f'''{Alphabet} ia a vowel''')

elif Alphabet == 'e':
  print(f'''{Alphabet} ia a vowel''')

elif Alphabet == 'i':
  print(f'''{Alphabet} ia a vowel''')

elif Alphabet == 'o':
  print(f'''{Alphabet} ia a vowel''')

elif Alphabet == 'u':
  print(f'''{Alphabet} ia a vowel''')

else:
  print(f'''{Alphabet} ia a consonant''')
# Out:
# Enter the alphabet: e
# e ia a vowel
