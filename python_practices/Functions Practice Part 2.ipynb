# %%
number = int(input('Enter the number'))

def is_even(number):
  """
  This function tells the given number is even or odd
  Input: Any valid integer
  Output: Even/Odd
  Created by: Abdullah Zeeshan
  Last edited: 8th Nov 2024
  """

  if number % 2 == 0:
    print('Even')

  else:
    print('Odd')

is_even(number)
# Out:
# Odd

# %%
def is_even(number):
  """
  This function tells the given number is even or odd
  Input: Any valid integer
  Output: Even/Odd
  Created by: Abdullah Zeeshan
  Last edited: 8th Nov 2024
  """

  if number % 2 == 0:
    return 'Even'

  else:
    return 'Odd'

for i in range(1,11):
  print(is_even(i))

print(is_even.__doc__)
# Out:
# Odd
# Even
# Odd
# Even
# Odd
# Even
# Odd
# Even
# Odd
# Even
#
#   This function tells the given number is even or odd
#   Input: Any valid integer
#   Output: Even/Odd
#   Created by: Abdullah Zeeshan
#   Last edited: 8th Nov 2024

# %%
def is_even(number):
  """
  This function tells the given number is even or odd
  Input: Any valid integer
  Output: Even/Odd
  Created by: Abdullah Zeeshan
  Last edited: 8th Nov 2024
  """

  if type(number) == int:
    if number % 2 == 0:
      return 'Even'

    else:
      return 'Odd'

  else:
    print('Not allowed')

is_even('jhvs')
# Out:
# 'Even'

# %%
def is_even(number):
  """
  This function tells the given number is even or odd
  Input: Any valid integer
  Output: Even/Odd
  Created by: Abdullah Zeeshan
  Last edited: 8th Nov 2024
  """

  if number % 2 == 0:
    return 'Even'

  else:
    return 'Odd'

x = is_even(5)
print(x)
# Out:
# Odd

# %%
def is_even(number):
  """
  This function tells the given number is even or odd
  Input: Any valid integer
  Output: Even/Odd
  Created by: Abdullah Zeeshan
  Last edited: 8th Nov 2024
  """

  if number % 2 == 0:
    print('Even')

  else:
    print('Odd')

x = is_even(5)
print(x)
# Out:
# Odd
# None
