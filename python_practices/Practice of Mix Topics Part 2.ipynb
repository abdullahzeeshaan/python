# %% [markdown]
# # **Default Parameter Value**

# %%
def greet(name = 'User'):
  return 'Hello, ' + name + '!'

print(greet('Abdullah'))
print(greet())
# Out:
# Hello, Abdullah!
# Hello, User!

# %% [markdown]
# # **Lambda Function**

# %%
cube = lambda x: x ** 3
print(cube(3))
# Out:
# 27
