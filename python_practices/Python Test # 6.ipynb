# %%
Name = input("Enter your name: ")
F_Name = input("Enter your fahter name: ")
Age = int(input("Enter your age: "))
Code = input("Enter the code: ")

if Age >= 18 and Code == "29531":
  print("You are eligible to vote and your area is NA232")

elif Code != "29531":
  print("Your code is false")
  Code = input("Again type")
  if Code == "29531":
      print("Code is correct. You are eligible to vote and your area is NA232")

  else:
      print("Code is incorrect")

else:
  print("You are not eligible to vote")
# Out:
# Enter your name: Abdullah
# Enter your fahter name: Saghir
# Enter your age: 18
# Enter the code: 29531
# You are eligible to vote and your area is NA232
